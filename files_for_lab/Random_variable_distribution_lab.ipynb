# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ### Get the numerical variables from our dataset.

# %%
numericals = customer_df.select_dtypes('number')

# %%
numericals
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
numericals.columns
# Out:
# Index(['Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies',
#        'Total Claim Amount'],
#       dtype='object')

# %% [markdown]
# ### Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for i in numericals.columns:
    sns.displot(numericals[i])
    plt.show()

# %% [markdown]
# - Variables (i.e.Customer Lifetime Value,income,Total Claim Amount) fit exponential distribution.
# - Varibales (i.e. 'Monthly Premium Auto','Months Since Last Claim', 'Months Since Policy Inception','Number of Open Complaints', 'Number of Policies','Total Claim Amount') fit normal distribution.

# %% [markdown]
# ### Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %% [markdown]
# There are many types of transformations for better normal distributions:
# - Log Transformation
# - Box-Cox Transformation
# - Square-Root Transformation
# - Reciprocal Transformation
# - Yeo-Johnson Transformation

# %%
# log transformation

# %%
numericals['Customer Lifetime Value'] = np.log(numericals['Customer Lifetime Value'])
plt.hist(numericals['Customer Lifetime Value'])
plt.show()

# %%
numericals['Total Claim Amount'] = np.log(numericals['Total Claim Amount'])
plt.hist(numericals['Total Claim Amount'])
plt.show()

# %%
# box-cox transformation

# %%
from scipy.stats import boxcox
numericals['Customer Lifetime Value'] = boxcox(numericals['Customer Lifetime Value'], 0.3)
plt.hist(numericals['Customer Lifetime Value'])
plt.show()

# %%
numericals['Total Claim Amount'] = boxcox(numericals['Total Claim Amount'], 0.3)
plt.hist(numericals['Total Claim Amount'])
plt.show()
